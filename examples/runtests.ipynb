# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_examples()
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=0.24999999897605943
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.0000000033745444, 0.0] with weight 0.999999996025421
#   0.010496 seconds (10.64 k allocations: 1.186 MiB)
#
# .................................
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=6
#   Number of trace equality constraints: m=19
#   0.044346 seconds (51.24 k allocations: 2.575 MiB)
# WARNING: replacing module SpectralSOS.
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        32
# N. func. eval.:  41
# Final value:     -0.062499
# Execution time:  0.067413
#   1.121968 seconds (721.38 k allocations: 39.827 MiB)
# ...

# %%
data="/home/hoanganh/Desktop/math-topics/SpectralPOP/codes/dataPOP"
# Out:
# "/home/hoanganh/Desktop/math-topics/SpectralPOP/codes/dataPOP"

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_quadratic_on_sphere(data)
# Out:
# ***Problem setting***
# Number of variables: n=50
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxation order: k=
# WARNING: replacing module SpectralSOS.
# 1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-6.248442746989442
#   0.497014 seconds (208.18 k allocations: 49.503 MiB, 3.12% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=51
#   Number of trace equality constraints: m=2
#   0.963120 seconds (1.55 M allocations: 97.480 MiB, 2.11% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        9
# N. func. eval.:  9
# Final value:     0.272251
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_equality_constrained_QCQP_on_sphere_first_order(data)
# Out:
# ***Problem setting***
# Number of variables: n=50
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=14
# ...
# Relaxation order: k=1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-4.265164735066031
#   0.639885 seconds (585.12 k allocations: 98.490 MiB, 3.08% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=51
#   Number of trace equality constraints: m=15
#   0.349315 seconds (1.31 M allocations: 167.557 MiB, 15.39% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       15
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        121
# N. func. eval.:  314
# Final value:     0.196681
# Execution time:  0.464310
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_equality_constrained_QCQP_on_sphere_second_order(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-2.4382266663486063
#   0.022581 seconds (43.56 k allocations: 7.527 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=21
#   Number of trace equality constraints: m=169
#   0.076915 seconds (66.22 k allocations: 4.460 MiB, 37.94% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        15
# N. func. eval.:  18
# Final value:     0.646832
# Execution time:  0.063232
# ...

# %%
SpectralSOS.Evaluation_comparisons(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=21
#   Number of trace equality constraints: m=169
#   0.002851 seconds (16.01 k allocations: 1.957 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        15
# N. func. eval.:  18
# Final value:     0.646832
# Execution time:  0.017365
#   0.018533 seconds (5.81 k allocations: 630.094 KiB)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=-2.438237062422687
# ...
# Dimension of the null space of Gram matrix = 1
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_QCQP_unique_inequality_ball_constraint(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of inequality constraints: l_g=1
# ...
# Number of equality constraints: l_h=2
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-0.33125818864465717
#   2.146333 seconds (3.70 M allocations: 198.677 MiB, 3.13% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=28
#   Number of trace equality constraints: m=281
#   0.045918 seconds (74.77 k allocations: 5.516 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       281
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        35
# N. func. eval.:  43
# Final value:     0.066468
# Execution time:  0.073914
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_QCQP_on_ball(data)
# Out:
# ***Problem setting***
# Number of variables: n=10
# ...
# Number of inequality constraints: l_g=2
# ...
# Number of equality constraints: l_h=2
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-3.177924554562845
#   0.398372 seconds (372.60 k allocations: 70.531 MiB, 10.64% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Computing the upper bound 1
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=78
#   Number of trace equality constraints: m=1951
#   0.090582 seconds (281.63 k allocations: 39.703 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1951
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     3
# N. iter.:        31
# N. func. eval.:  121
# Final value:     0.132783
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.Norm_Subgrad(data)
# Out:
# ***POP with single inequality (ball) constraint***
# Number of variables: n=10
# ...
# Number of inequality constraints: l_g=1
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxation order: k=2
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=78
#   Number of trace equality constraints: m=2029
#   0.145063 seconds (356.08 k allocations: 51.757 MiB, 24.78% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2029
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        64
# N. func. eval.:  75
# Final value:     0.372055
# Execution time:  0.165192
#   1.249160 seconds (867.54 k allocations: 61.569 MiB)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=-2.3041178161428446
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_random_dense_quartics_on_sphere(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-2.9248306849962558
#   0.022078 seconds (31.75 k allocations: 6.388 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=21
#   Number of trace equality constraints: m=127
#   0.045041 seconds (58.41 k allocations: 3.435 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       127
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        30
# N. func. eval.:  38
# Final value:     0.284584
# Execution time:  0.072083
# ...

# %%
include("../src/SpectralSOS.jl")
using .SpectralSOS

SpectralSOS.test_deciding_nonnegativity(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-2.6235367991735883
#   0.019909 seconds (31.00 k allocations: 6.304 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=21
#   Number of trace equality constraints: m=127
#   0.048855 seconds (57.68 k allocations: 3.374 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       127
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        266
# N. func. eval.:  547
# Final value:     0.184743
# Execution time:  0.282532
#   1.289934 seconds (874.22 k allocations: 56.971 MiB)
# ...

# %%
SpectralSOS.test_deciding_copositivity(data)
# Out:
# ***Problem setting***
# Number of variables: n=10
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-0.89102344150825
#   0.310242 seconds (243.23 k allocations: 57.502 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=66
#   Number of trace equality constraints: m=1277
#   0.018123 seconds (60.95 k allocations: 9.283 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1277
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        197
# N. func. eval.:  419
# Final value:     0.070405
# Execution time:  1.240234
#   1.034690 seconds (352.59 k allocations: 79.217 MiB, 2.56% gc time)
# ...

# %%
SpectralSOS.test_deciding_convexity(data)
# Out:
# ***Problem setting***
# Number of variables: n=5
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxation order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-3.8735075654977478
#   0.315105 seconds (246.65 k allocations: 57.682 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Constant trace property (CTP):
# **Converting the moment relaxation to the standard SDP:
#   Size of psd matrix: sk=66
#   Number of trace equality constraints: m=1277
#   0.075785 seconds (66.55 k allocations: 9.786 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1277
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        372
# N. func. eval.:  650
# Final value:     0.119654
# Execution time:  1.141113
#   0.994267 seconds (398.39 k allocations: 117.096 MiB, 3.17% gc time)
# ...
