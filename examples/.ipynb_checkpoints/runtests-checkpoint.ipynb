# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

SpectralPOP.test_examples()
# Out:
# ****Test polynomial optimization****
# **SumOfSquares+Mosek:
# WARNING: replacing module SpectralPOP.
# OPTIMAL
# opt_val=0.2499999989810142
# Atomic measure on the variables x[1], x[2] with 1 atoms:
#  at [-1.000000003373059, 0.0] with weight 0.9999999960287472
#  30.430036 seconds (56.57 M allocations: 2.797 GiB, 5.13% gc time)
#
# .................................
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=6
#   Number of equality trace constraints: m=19
#   1.182082 seconds (2.23 M allocations: 105.148 MiB, 2.26% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       19
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        18
# N. func. eval.:  21
# Final value:     -0.250000
# Execution time:  1.105095
#   1.523545 seconds (1.64 M allocations: 88.563 MiB, 3.53% gc time)
# ...

# %%
data="/home/hoanganh/Desktop/math-topics/SpectralPOP/codes/dataPOP"
# Out:
# "/home/hoanganh/Desktop/math-topics/SpectralPOP/codes/dataPOP"

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

SpectralPOP.test_random_dense_quadratic_on_sphere(data)
# Out:
# ***Problem setting***
# Number of variable: n=50
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxed order: k=
# WARNING: replacing module SpectralPOP.
# 1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-6.185408130664582
#   4.664114 seconds (7.65 M allocations: 424.260 MiB, 4.00% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=2
#   0.111122 seconds (114.22 k allocations: 27.317 MiB, 31.88% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        5
# N. func. eval.:  5
# Final value:     6.185408
# Execution time:  0.070297
# ...

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

SpectralPOP.test_random_dense_equality_constrained_QCQP_on_sphere_first_order(data)
# Out:
# ***Problem setting***
# Number of variable: n=50
# ...
# Number of inequality constraints: l_g=0
# ...
# Number of equality constraints: l_h=14
# ...
# Relaxed order: k=
# WARNING: replacing module SpectralPOP.
# 1
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-5.029803941682497
#   0.391210 seconds (844.36 k allocations: 106.100 MiB, 3.89% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=51
#   Number of equality trace constraints: m=15
#   0.151707 seconds (378.16 k allocations: 137.411 MiB, 18.59% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       15
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        23
# N. func. eval.:  25
# Final value:     5.029805
# Execution time:  0.047737
# ...

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

SpectralPOP.test_random_dense_equality_constrained_QCQP_on_sphere_second_order(data)
# Out:
# ***Problem setting***
# Number of variable: n=5
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# WARNING: replacing module SpectralPOP.
# OPTIMAL
# opt_val=0.2115731816772126
#   0.028626 seconds (83.20 k allocations: 9.018 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=21
#   Number of equality trace constraints: m=169
#   0.071942 seconds (65.45 k allocations: 4.262 MiB, 35.97% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        58
# N. func. eval.:  71
# Final value:     -0.211569
# Execution time:  0.092896
#   0.251542 seconds (272.32 k allocations: 16.707 MiB)
# ...

# %%
SpectralPOP.Evaluation_comparisons(data)
# Out:
# ***Problem setting***
# Number of variable: n=5
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=21
#   Number of equality trace constraints: m=169
#   0.001832 seconds (15.24 k allocations: 1.759 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       169
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        14
# N. func. eval.:  15
# Final value:     0.898812
# Execution time:  0.047363
#   0.048101 seconds (123.71 k allocations: 6.579 MiB)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=-0.8988120590646012
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_random_dense_QCQP_unique_inequality_ball_constraint(data)
# Out:
# ***Problem setting***
# Number of variable: n=5
# ...
# Number of inequality constraints: l_g=1
# ...
# Number of equality constraints: l_h=2
# ...
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-0.8446062448770507
#   0.222986 seconds (228.37 k allocations: 16.414 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=28
#   Number of equality trace constraints: m=281
#   0.003018 seconds (23.75 k allocations: 2.733 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       281
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        35
# N. func. eval.:  44
# Final value:     0.844607
# Execution time:  0.024490
#   0.025440 seconds (14.78 k allocations: 2.119 MiB)
# ...

# %%
SpectralPOP.test_random_dense_QCQP_on_ball(data)
# Out:
# ***Problem setting***
# Number of variable: n=10
# ...
# Number of inequality constraints: l_g=2
# ...
# Number of equality constraints: l_h=2
# ...
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-3.364640336161263
#   0.580349 seconds (876.77 k allocations: 95.830 MiB, 5.13% gc time)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Conpute upper bound 1
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=1951
#   0.043211 seconds (228.47 k allocations: 35.119 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1951
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        144
# N. func. eval.:  288
# Final value:     0.692622
# Execution time:  0.375122
# ...

# %%
SpectralPOP.Norm_Subgrad(data)
# Out:
# ***POP with single inequality (ball) constraint***
# Number of variable: n=10
# ...
# Number of inequality constraints: l_g=1
# ...
# Number of equality constraints: l_h=3
# ...
# Relaxed order: k=2
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=2029
#   0.079681 seconds (301.64 k allocations: 46.644 MiB, 31.80% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2029
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        20
# N. func. eval.:  23
# Final value:     3.621555
# Execution time:  0.019928
#   0.021458 seconds (11.48 k allocations: 5.568 MiB)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=-3.621554641133053
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_random_dense_quartics_on_sphere(data)
# Out:
# ***Problem setting***
# Number of variable: n=5
# ...
# Number of equality constraints: l_h=1
# ...
# Relaxed order: k=2
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **SumOfSquares+Mosek:
# OPTIMAL
# opt_val=-3.0936723267660318
#   0.021725 seconds (70.78 k allocations: 7.881 MiB)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=21
#   Number of equality trace constraints: m=127
#   0.000893 seconds (7.22 k allocations: 837.453 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       127
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        41
# N. func. eval.:  52
# Final value:     3.093674
# Execution time:  0.023087
#   0.024011 seconds (16.17 k allocations: 1.756 MiB)
# ------------------------------------
# **Numerical result:
# ...

# %%
SpectralPOP.test_chemkin()
# Out:
# chemkin
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=78
#   Number of equality trace constraints: m=2575
#   0.028755 seconds (126.48 k allocations: 19.657 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       2575
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        6386
# N. func. eval.:  15976
# Final value:     -1.898086
# Execution time:  44.203949
#  44.252391 seconds (17.31 M allocations: 3.992 GiB, 1.04% gc time)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=1.8980858525778062
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_d1()
# Out:
# d1
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=105
#   Number of equality trace constraints: m=4343
#   0.067483 seconds (206.66 k allocations: 34.866 MiB, 35.85% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4343
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        826
# N. func. eval.:  1579
# Final value:     -1.887831
# Execution time:  22.647614
#   7.538997 seconds (1.42 M allocations: 662.245 MiB, 0.95% gc time)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=1.8878313992380313
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_katsura7()
# Out:
# katsura7
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=55
#   Number of equality trace constraints: m=1321
#   0.015254 seconds (82.85 k allocations: 11.895 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1321
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        550
# N. func. eval.:  1164
# Final value:     -1.876974
# Execution time:  1.101257
#   1.113948 seconds (558.68 k allocations: 153.642 MiB, 3.95% gc time)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=1.8769741980609123
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_stewgou()
# Out:
# stewgou
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=66
#   Number of equality trace constraints: m=1871
#   0.017434 seconds (106.60 k allocations: 15.278 MiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       1871
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        657
# N. func. eval.:  1146
# Final value:     -1.847157
# Execution time:  1.470947
#   1.472218 seconds (647.22 k allocations: 225.916 MiB, 2.33% gc time)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=1.8471571908489621
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_ku10()
# Out:
# ku10
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=12
#   Number of equality trace constraints: m=12
#   0.000515 seconds (3.63 k allocations: 456.688 KiB)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       12
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     1
# N. iter.:        4
# N. func. eval.:  5
# Final value:     -0.000688
# Execution time:  0.000488
#   0.001365 seconds (2.52 k allocations: 114.016 KiB)
# ------------------------------------
# **Numerical result:
# ...
# opt_val=0.0006879438861853967
# ...
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# ...

# %%
SpectralPOP.test_kin1()
# Out:
# kin1
# ------------------------------------
# Determine omega1:
# **Convert moment relaxation to standard SDP:
#   Size of psd matrix: sk=105
#   Number of equality trace constraints: m=4343
#   0.068335 seconds (206.67 k allocations: 34.867 MiB, 28.18% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       4343
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# InterruptException:
#
# Stacktrace:
#  [1] aupd_wrapper(::Type, ::Arpack.var"#matvecA!#24"{Array{Float64,2}}, ::Arpack.var"#18#25", ::Arpack.var"#19#26", ::Int64, ::Bool, ::Bool, ::String, ::Int64, ::Int64, ::String, ::Float64, ::Int64, ::Int64, ::Array{Float64,1}) at /home/hoanganh/.julia/packages/Arpack/o35I5/src/libarpack.jl:79
# ...
